# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/ditiansm2015/ML-May-28/blob/master/assignment_4.ipynb)

# %% [markdown]
# SUDHANSHU MISHRA
#
# Machine Learning with Python (SUM18 ML ON1)
#
# ASSIGNMENT_4

# %%
#Question 1
#Create a dataframe with your name , age , mail id and phone 
#number and add your friends’s information to the same.


import pandas as pd

#Creating our own dataset using python dictionary
record={'NAME':['Sudhanshu','Rahul'],'AGE':[21,19],'MAIL ID':['ditiansm2015@gmail.com','rahul1212@gmail.com'],'PHONE':[9454764310,8576892748]}

#DataFrame() creates a dataframe(table) comprising all the elements of dictionary
df=pd.DataFrame(record)


#setting the order for columns in which they should appear else they would be set in random fashion
df = df[['NAME', 'AGE', 'MAIL ID','PHONE']]

print("Before adding new records:\n",df,"\n\n")

#Appending 2 more rows/records to the dataframe
df.loc[2] = ['Shreyas', 72, 'shreyas3108@gmail.com',8548754687]
df.loc[3] = ['Himanshu',56, 'himanshu205@gmail.com',8548724787]


#df.append({'NAME':['Shreyas'], 'AGE':[72],'MAIL ID':['shreyas3108@gmail.com'],'PHONE':[8858745877]},ignore_index=True)

print("After adding new records:\n",df,"\n\n")
# Out:
# Before adding new records:
#          NAME  AGE                 MAIL ID       PHONE
# 0  Sudhanshu   21  ditiansm2015@gmail.com  9454764310
# 1      Rahul   19     rahul1212@gmail.com  8576892748
#
#
# After adding new records:
#          NAME  AGE                 MAIL ID       PHONE
# 0  Sudhanshu   21  ditiansm2015@gmail.com  9454764310
# 1      Rahul   19     rahul1212@gmail.com  8576892748
# 2    Shreyas   72   shreyas3108@gmail.com  8548754687
# 3   Himanshu   56   himanshu205@gmail.com  8548724787

# %%
#Question 2
#Download the dataset from this link :
#https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv
 
#Import the data and print the following :
#a.) First 5 rows of Dataframe 
#b.) First 10 rows of the Dataframe 
#c.) find basic statistics on the particular dataset. 
#d.) Find the last 5 rows of the dataframe 
#e.) Extract the 2nd column and find basic statistics on it.


import pandas as pd

#Reading CSV file from the given link
df=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")

#Printing first five rows of dataframe(no argument inside head() automatically prsents first 5 rows)
firstFiveRows=df.head()
print("\nFirst Five Rows are:\n\n",firstFiveRows)

print("\n\n------------------------------------------------------------------\n\n")

#Printing first ten rows of dataframe(head(n) gives first n rows of dataframe)
firstTenRows=df.head(10)
print("\n\nFirst Ten Rows are:\n\n",firstTenRows)

print("\n\n------------------------------------------------------------------\n\n")

#Basic statistics of dataframe(describe()gives complete detail of the dataset)
statistics=df.describe(include="all")
print("\n\nStatistics of the dataset:\n\n",statistics)

print("\n\n------------------------------------------------------------------\n\n")

#Last five rows of dataframe
lastFiveRows=df.tail()
print("\n\nLast Five Rows are:\n\n",lastFiveRows)

print("\n\n------------------------------------------------------------------\n\n")

#Statistics of Second column
secColStats=df['Location'].describe(include='all')
print("\n\nSecond Column Statistics:\n\n",secColStats)
# Out:
# First Five Rows are:
#
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
